# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
abia_power = pd.read_csv('../Data/Power Sources of selected  PHCs in Abia State - Power source.csv')
anambra_power = pd.read_csv('../Data/Power Sources of selected  PHCs in Anambra - Sheet2.csv')
Sokoto_power = pd.read_csv('../Data/Power Sources of selected  PHCs in Sokoto State - Sheet2.csv')
