# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # infrastructure data

# %%
Ceiling = pd.read_csv("../Data/Infrastructure/Availability of Broken Ceiling by  selected  PhC's in Taraba State - Broken Ceiling.csv")
chairs = pd.read_csv("../Data/Infrastructure/Availability of Damaged Chairs across selected PHCs in Taraba State - Damaged Chairs.csv")
doors = pd.read_csv("../Data/Infrastructure/Availability of Damaged Doors across selected PHCs in Taraba State - Damaged Doors.csv")
delivery_beds = pd.read_csv("../Data/Infrastructure/Availability of Delivery Beds across selected PHCs in Taraba - Sheet2.csv")
icu_availability = pd.read_csv("../Data/Infrastructure/Availability of Functional Pharmacy _ Intensive Care Unit of selected PHCs in Taraba State - Phc Premises.csv")
leaking_roofs = pd.read_csv("../Data/Infrastructure/Availability of Leaking Roofs across selected PHCs in Taraba State - Leaking Roof.csv")
neonatal_equipment = pd.read_csv("../Data/Infrastructure/Availability of Neonatal Care Equipment across selected PHCs in Taraba - Sheet2.csv")
waste_disposal = pd.read_csv("../Data/Infrastructure/Availability of Waste Disposals across selected PHCs in Taraba State - Sheet3.csv")
building_structures = pd.read_csv("../Data/Infrastructure/Evaluation of Building Structures in Selected Taraba State PHC's - Building Structures.csv")
restrooms = pd.read_csv("../Data/Infrastructure/Functional Restrooms in Reviewed PHCs – Taraba - Sheet2.csv")
hospital_beds = pd.read_csv("../Data/Infrastructure/Hospital Beds in Reviewed PHCs – Taraba State - taraba_state_phc_data.csv")
wards = pd.read_csv("../Data/Infrastructure/Wards by Reviewed PHC in Taraba State - taraba_state_phc_data.csv")

# %% [markdown]
# # Service delivery

# %%
quality = pd.read_csv("../Data/Service delivery/Assessment of Treatment, Immunization, and Overall Service Quality across selected PHCs in Taraba - Sheet2.csv")
availability = pd.read_csv("../Data/Service delivery/Availability of Health Workers in selected PHCs in Taraba - Sheet2.csv")
staff_training = pd.read_csv("../Data/Service delivery/Availability of Training and Development Opportunities for Staff across selected PHCs in Taraba - Sheet2.csv")
referrals = pd.read_csv("../Data/Service delivery/Referrals to Larger Hospitals and Reasons across selected PHCs in Taraba - Sheet2.csv")
supply_shortages = pd.read_csv("../Data/Service delivery/Shortages of Medical Supplies (Syringes and Bandages) in Reviewed PHCs – Taraba - Sheet2.csv")
ppe_shortages = pd.read_csv("../Data/Service delivery/Shortages of PPE'S in Reviewed PHCs – Taraba - Sheet2.csv")
staff_satisfaction = pd.read_csv("../Data/Service delivery/Staff Satisfaction with Working Conditions across selected PHCs in Taraba - Sheet2.csv")
