# %%
import pandas as pd
from functools import reduce

# %% [markdown]
# # infrastructure data

# %%
Ceiling = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Broken Ceiling by  selected  PhC's in Taraba State - Broken Ceiling.csv")
chairs = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Damaged Chairs across selected PHCs in Taraba State - Damaged Chairs.csv")
doors = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Damaged Doors across selected PHCs in Taraba State - Damaged Doors.csv")
delivery_beds = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Delivery Beds across selected PHCs in Taraba - Sheet2.csv")
icu_availability = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Functional Pharmacy _ Intensive Care Unit of selected PHCs in Taraba State - Phc Premises.csv")
leaking_roofs = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Leaking Roofs across selected PHCs in Taraba State - Leaking Roof.csv")
neonatal_equipment = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Neonatal Care Equipment across selected PHCs in Taraba - Sheet2.csv")
waste_disposal = pd.read_csv("../Data/unconsolidated/Infrastructure/Availability of Waste Disposals across selected PHCs in Taraba State - Sheet3.csv")
building_structures = pd.read_csv("../Data/unconsolidated/Infrastructure/Evaluation of Building Structures in Selected Taraba State PHC's - Building Structures.csv")
restrooms = pd.read_csv("../Data/unconsolidated/Infrastructure/Functional Restrooms in Reviewed PHCs – Taraba - Sheet2.csv")
hospital_beds = pd.read_csv("../Data/unconsolidated/Infrastructure/Hospital Beds in Reviewed PHCs – Taraba State - taraba_state_phc_data.csv")
wards = pd.read_csv("../Data/unconsolidated/Infrastructure/Wards by Reviewed PHC in Taraba State - taraba_state_phc_data.csv")

# %%
Ceiling.head(10)
# Out:
#                   Name of Primary Health Center    PHC LGA  State of PHC  \
# 0                           Anguwan Dampar Phcc        Ibi  Taraba State
# 1               First Referral Hospital Sunkani  Ardo-kola  Taraba State
# 2                               Garin Jatau Phc  Ardo-kola  Taraba State
# 3  Primary Health Care Rafin Damisa Dispensary.        Ibi  Taraba State
# 4                       Phcc Sarki Kudu Ibi Lga        Ibi  Taraba State
# 5            Primary Health Care Center  Mallum  Ardo-kola  Taraba State
# 6           Pamanga Primary Health Care Centers       Bali  Taraba State
# 7                 Kankani Primary Health Clinic       Bali  Taraba State
# 8             Dankum Primary Health Care Center      Yorro  Taraba State
# 9             Kajong Primary Health Care Center      Yorro  Taraba State
#
#   Check for any of these building failures./Broken Celling
# 0                                                 No
# ...

# %%
Ceiling.describe()
# Out:
#                      Name of Primary Health Center PHC LGA  State of PHC  \
# count                                           75      75            75
# unique                                          74      24             1
# top     Sala Duna Dispensary Primary Health Center  Wukari  Taraba State
# freq                                             2       7            75
#
#        Check for any of these building failures./Broken Celling
# count                                                  75
# unique                                                  2
# top                                                   Yes
# freq                                                   54

# %%
Ceiling['Name of Primary Health Center'].nunique()
# Out:
# 74

# %%
leaking_roofs.describe()
# Out:
#                      Name of Primary Health Center PHC LGA  State of PHC  \
# count                                           75      75            75
# unique                                          74      24             1
# top     Sala Duna Dispensary Primary Health Center  Wukari  Taraba State
# freq                                             2       7            75
#
#        Check for any of these building failures./Damaged/Leaking roofs
# count                                                  75
# unique                                                  2
# top                                                   Yes
# freq                                                   47

# %%
leaking_roofs['Name of Primary Health Center'].nunique()
# Out:
# 74

# %%
wards.describe()
# Out:
#                      Name of Primary Health Center  State of PHC  \
# count                                           75            75
# unique                                          74             1
# top     Sala Duna Dispensary Primary Health Center  Taraba State
# freq                                             2            75
#
#        How many wards in Total do you
# count                              73
# unique                             10
# top                                 2
# freq                               32

# %% [markdown]
# ## consolidating the infrastructure data

# %%
for i in list_of_dataframes:
    print(i.columns)
    print()
    print()
# Out:
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Check for any of these building failures./Broken Celling'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Check for any of these building failures./Damaged Chairs'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Check for any of these building failures./Damaged Door'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Which of these Equipment are Available Labor Ward(Delivery Bed)?'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Does the PHC have these Areas within the Premises(Functional Pharmacy)?',
#        'Does the PHC have these Areas within the Premises(Intensive Care Unit)?'],
#       dtype='object')
#
#
# ...

# %%
list_of_dataframes = [
    Ceiling,
    chairs,
    doors,
    delivery_beds,
    icu_availability,
    leaking_roofs,
    neonatal_equipment,
    waste_disposal,
    building_structures,
    restrooms,
    hospital_beds,
]
#wards column is not in the list of dataframes

common_column = ['Name of Primary Health Center','PHC LGA', 'State of PHC']
merged_df = reduce(lambda left, right: pd.merge(left, right, on=common_column, how='outer'), list_of_dataframes)
final_df = pd.merge(merged_df, wards, on='Name of Primary Health Center', how='outer')
df = final_df.loc[:, ~final_df.columns.str.contains('^Unnamed')]

# %%
df.columns
# Out:
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC_x',
#        'Check for any of these building failures./Broken Celling',
#        'Check for any of these building failures./Damaged Chairs',
#        'Check for any of these building failures./Damaged Door',
#        'Which of these Equipment are Available Labor Ward(Delivery Bed)?',
#        'Does the PHC have these Areas within the Premises(Functional Pharmacy)?',
#        'Does the PHC have these Areas within the Premises(Intensive Care Unit)?',
#        'Check for any of these building failures./Damaged/Leaking roofs',
#        'Which of these Equipment are Available Labor Ward(Fetal Heart Rate Monitor)?',
#        'Which of these Equipment are Available Labor Ward(Neo-Natal Resuscitation Equipment)?',
#        'How is Hospital Waste Disposed?',
#        'Specify Other Ways of Disposing Waste by the PHC?',
#        'Does the health care center have a well-built and Maintained structure ?',
# ...

# %%
df.to_csv("../Data/infrastructure.csv", index=False)

# %% [markdown]
# # Service delivery

# %%
quality = pd.read_csv("../Data/unconsolidated/Service delivery/Assessment of Treatment, Immunization, and Overall Service Quality across selected PHCs in Taraba - Sheet2.csv")
availability = pd.read_csv("../Data/unconsolidated/Service delivery/Availability of Health Workers in selected PHCs in Taraba - Sheet2.csv")
staff_training = pd.read_csv("../Data/unconsolidated/Service delivery/Availability of Training and Development Opportunities for Staff across selected PHCs in Taraba - Sheet2.csv")
referrals = pd.read_csv("../Data/unconsolidated/Service delivery/Referrals to Larger Hospitals and Reasons across selected PHCs in Taraba - Sheet2.csv")
supply_shortages = pd.read_csv("../Data/unconsolidated/Service delivery/Shortages of Medical Supplies (Syringes and Bandages) in Reviewed PHCs – Taraba - Sheet2.csv")
ppe_shortages = pd.read_csv("../Data/unconsolidated/Service delivery/Shortages of PPE'S in Reviewed PHCs – Taraba - Sheet2.csv")
staff_satisfaction = pd.read_csv("../Data/unconsolidated/Service delivery/Staff Satisfaction with Working Conditions across selected PHCs in Taraba - Sheet2.csv")

# %%
list_of_service_delivery_dataframes = [
    quality,
    availability,
    staff_training,
    referrals,
    supply_shortages,
    ppe_shortages,
    staff_satisfaction,
]
for i in list_of_service_delivery_dataframes:
    print(i.columns)
    print()
    print()
# Out:
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Rate the Quality of Treatment in this PHC',
#        'Rate the Immunization Services Provided in the PHC',
#        'Give a General Rating for the PHC'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Mention the Position of Health worker and Number at the PHC?'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Are there regular training and development opportunities for staff members?'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'How many Referrals to Larger Hospitals have occurred in the last 1 year',
#        'Reasons for Referral'],
#       dtype='object')
#
#
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Identify Shortages of Medical Supplies(Syringes)?',
# ...

# %%
merged_df = reduce(lambda left, right: pd.merge(left, right, on=common_column, how='outer'), list_of_service_delivery_dataframes)
service_delivery_df = merged_df.loc[:, ~merged_df.columns.str.contains('^Unnamed')]

# %%
service_delivery_df.columns
# Out:
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Rate the Quality of Treatment in this PHC',
#        'Rate the Immunization Services Provided in the PHC',
#        'Give a General Rating for the PHC',
#        'Mention the Position of Health worker and Number at the PHC?',
#        'Are there regular training and development opportunities for staff members?',
#        'How many Referrals to Larger Hospitals have occurred in the last 1 year',
#        'Reasons for Referral',
#        'Identify Shortages of Medical Supplies(Syringes)?',
#        'Identify Shortages of Medical Supplies(Bandages)?',
#        'Identify Shortages of Medical Supplies(Personal Protective Equipment)?',
#        'Are the staff members satisfied with their working conditions?'],
#       dtype='object')

# %%
service_delivery_df.to_csv("../Data/service_delivery.csv", index=False)

# %% [markdown]
# # Telecommunication

# %%
transportation_means = pd.read_csv("../Data/unconsolidated/telecommunication map/Common Means of Transportation to PHCs across selected Areas in Taraba - Sheet2.csv")

# %%
transportation_means.head(10)
# Out:
#                   Name of Primary Health Center    PHC LGA  State of PHC  \
# 0                           Anguwan Dampar Phcc        Ibi  Taraba State
# 1               First Referral Hospital Sunkani  Ardo-kola  Taraba State
# 2                               Garin Jatau Phc  Ardo-kola  Taraba State
# 3  Primary Health Care Rafin Damisa Dispensary.        Ibi  Taraba State
# 4                       Phcc Sarki Kudu Ibi Lga        Ibi  Taraba State
# 5             Primary Health Care Center Mallum  Ardo-kola  Taraba State
# 6           Pamanga Primary Health Care Centers       Bali  Taraba State
# 7                 Kankani Primary Health Clinic       Bali  Taraba State
# 8             Dankum Primary Health Care Center      Yorro  Taraba State
# 9             Kajong Primary Health Care Center      Yorro  Taraba State
#
#   Identify 2 most common means of Transportation to PHC
# 0               On Foot,Motor Cycle (Bike or OKada),
# 1     Keke Maruwa, On Foot,Public Cars,Public Buses,
# ...

# %%
transportation_means.describe()
# Out:
#                      Name of Primary Health Center PHC LGA  State of PHC  \
# count                                           75      75            75
# unique                                          74      17             2
# top     Sala Duna Dispensary Primary Health Center   Takum  Taraba State
# freq                                             2       8            74
#
#        Identify 2 most common means of Transportation to PHC
# count                                                  75
# unique                                                 39
# top                   On Foot Motor Cycle (Bike or OKada)
# freq                                                    9

# %%
transportation_means.columns
# Out:
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'Identify 2 most common means of Transportation to PHC'],
#       dtype='object')

# %%
transportation_means.to_csv("../Data/telecommunication.csv", index=False)

# %% [markdown]
# # Inclusivity

# %%
communities_served = pd.read_csv("../Data/unconsolidated/inclusivity/Communities Served by each PHC across selected PHCs in Taraba - Sheet2.csv")

# %%
communities_served.head(10)
# Out:
#                   Name of Primary Health Center    PHC LGA  State of PHC  \
# 0                           Anguwan Dampar Phcc        Ibi  Taraba State
# 1               First Referral Hospital Sunkani  Ardo-kola  Taraba State
# 2                               Garin Jatau Phc  Ardo-kola  Taraba State
# 3  Primary Health Care Rafin Damisa Dispensary.        Ibi  Taraba State
# 4                       Phcc Sarki Kudu Ibi Lga        Ibi  Taraba State
# 5             Primary Health Care Center Mallum  Ardo-kola  Taraba State
# 6           Pamanga Primary Health Care Centers       Bali  Taraba State
# 7                 Kankani Primary Health Clinic       Bali  Taraba State
# 8             Dankum Primary Health Care Center      Yorro  Taraba State
# 9             Kajong Primary Health Care Center      Yorro  Taraba State
#
#   How Many Communities Rely on this PHC for Health Care
# 0                                    Greater than 10
# 1                                    Greater than 10
# ...

# %%
communities_served.dtypes
# Out:
# Name of Primary Health Center                            object
# PHC LGA                                                  object
# State of PHC                                             object
# How Many Communities Rely on this PHC for Health Care    object
# dtype: object

# %%
communities_served.describe()
# Out:
#                      Name of Primary Health Center PHC LGA  State of PHC  \
# count                                           75      75            75
# unique                                          74      17             2
# top     Sala Duna Dispensary Primary Health Center   Takum  Taraba State
# freq                                             2       8            74
#
#        How Many Communities Rely on this PHC for Health Care
# count                                                  75
# unique                                                 11
# top                                       Greater than 10
# freq                                                   28

# %%
communities_served.columns
# Out:
# Index(['Name of Primary Health Center', 'PHC LGA', 'State of PHC',
#        'How Many Communities Rely on this PHC for Health Care'],
#       dtype='object')

# %%
communities_served.to_csv("../Data/inclusivity.csv", index=False)
